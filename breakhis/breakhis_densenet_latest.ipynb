# %%
import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from tensorflow.keras import layers, models, Input
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from collections import defaultdict
from tensorflow.keras.models import load_model
from tensorflow.keras.metrics import Precision, Recall
import seaborn as sns
from PIL import Image
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'

# %%
SEED=42
BATCH_SIZE=16

# %%
base_path='/kaggle/input/breakhis/BreaKHis_v1/'

# %%
folds = pd.read_csv('/kaggle/input/breakhis/Folds.csv')

# %%
benign_classes = ['phyllodes_tumor', 'adenosis', 'fibroadenoma', 'tubular_adenoma']
malignant_classes = ['ductal_carcinoma', 'lobular_carcinoma', 'papillary_carcinoma', 'mucinous_carcinoma']

def get_labels(path):
    path_lower = path.lower()

    if 'benign' in path_lower:
        coarse_label = 'benign'
    else:
        coarse_label = 'malignant'

    fine_label = None
    for cls in benign_classes + malignant_classes:
        if cls in path_lower:
            fine_label = cls
            break

    return pd.Series([coarse_label, fine_label])

folds[['coarse_label', 'fine_label']] = folds['filename'].apply(get_labels)

# %%
folds['filename'] = folds['filename'].apply(lambda x: os.path.join(base_path, x))

# %%
folds.drop(columns=['fold','grp'], inplace=True)

# %%
folds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39545 entries, 0 to 39544
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mag           39545 non-null  int64
#  1   filename      39545 non-null  object
#  2   coarse_label  39545 non-null  object
#  3   fine_label    39545 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 1.2+ MB

# %%
folds.head(8)
# Out:
#    mag                                           filename coarse_label  \
# 0  100  /kaggle/input/breakhis/BreaKHis_v1/BreaKHis_v1...       benign
# 1  100  /kaggle/input/breakhis/BreaKHis_v1/BreaKHis_v1...       benign
# 2  100  /kaggle/input/breakhis/BreaKHis_v1/BreaKHis_v1...       benign
# 3  100  /kaggle/input/breakhis/BreaKHis_v1/BreaKHis_v1...       benign
# 4  100  /kaggle/input/breakhis/BreaKHis_v1/BreaKHis_v1...       benign
# 5  100  /kaggle/input/breakhis/BreaKHis_v1/BreaKHis_v1...       benign
# 6  100  /kaggle/input/breakhis/BreaKHis_v1/BreaKHis_v1...       benign
# 7  100  /kaggle/input/breakhis/BreaKHis_v1/BreaKHis_v1...       benign
#
#   fine_label
# 0   adenosis
# 1   adenosis
# 2   adenosis
# 3   adenosis
# 4   adenosis
# 5   adenosis
# 6   adenosis
# 7   adenosis

# %%
sns.displot(data=folds,x='coarse_label')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=folds, x='fine_label', height=6, aspect=2)
plt.xticks(rotation=40)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
test_df = folds.groupby('fine_label', group_keys=False).sample(n=850, random_state=SEED)
train_valid_df = folds.drop(test_df.index).reset_index(drop=True)
test_df = test_df.reset_index(drop=True)

valid_df = train_valid_df.groupby('fine_label', group_keys=False).sample(frac=0.25, random_state=SEED)
train_df = train_valid_df.drop(valid_df.index).reset_index(drop=True)
valid_df = valid_df.reset_index(drop=True)

print('Training Set: ')
print(train_df['fine_label'].value_counts())
print('Total Count: ', train_df.shape[0])

print('Validation Set:')
print(valid_df['fine_label'].value_counts())
print('Total Count: ', valid_df.shape[0])

print('Test Set:')
print(test_df['fine_label'].value_counts())
print('Total Count: ', test_df.shape[0])
# Out:
# Training Set:
# fine_label
# ductal_carcinoma       12304
# fibroadenoma            3165
# mucinous_carcinoma      2332
# lobular_carcinoma       1710
# tubular_adenoma         1496
# papillary_carcinoma     1462
# phyllodes_tumor         1061
# adenosis                1028
# Name: count, dtype: int64
# Total Count:  24558
# Validation Set:
# fine_label
# ductal_carcinoma       4101
# fibroadenoma           1055
# mucinous_carcinoma      778
# lobular_carcinoma       570
# tubular_adenoma         499
# papillary_carcinoma     488
# phyllodes_tumor         354
# adenosis                342
# Name: count, dtype: int64
# Total Count:  8187
# Test Set:
# fine_label
# adenosis               850
# ductal_carcinoma       850
# fibroadenoma           850
# lobular_carcinoma      850
# mucinous_carcinoma     850
# papillary_carcinoma    850
# phyllodes_tumor        850
# tubular_adenoma        850
# Name: count, dtype: int64
# Total Count:  6800

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Count occurrences of each mag per dataset
train_counts = train_df['mag'].value_counts().sort_index()
valid_counts = valid_df['mag'].value_counts().sort_index()
test_counts  = test_df['mag'].value_counts().sort_index()

# Combine into one DataFrame for comparison
mag_counts_df = pd.DataFrame({
    'Train': train_counts,
    'Validation': valid_counts,
    'Test': test_counts
}).fillna(0).astype(int)

# Display table (optional)
print(mag_counts_df.head())

# Plot side-by-side bars
mag_counts_df.plot(kind='bar', figsize=(16, 8))
plt.title('Count of Each "mag" Value Across Datasets', fontsize=18, fontweight='bold')
plt.xlabel('Magnitude (mag)', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.legend(title='Dataset', fontsize=12)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
#      Train  Validation  Test
# mag
# 40    6081        2091  1803
# 100   6510        2140  1755
# 200   6281        2087  1697
# 400   5686        1869  1545

# %%
#upsampling
max_count = np.max(train_df.fine_label.value_counts())
min_count = np.min(train_df.fine_label.value_counts())
train_df = train_df.groupby('fine_label').sample(n=max_count, replace=True)
train_df = train_df.reset_index(drop=True)
train_df.fine_label.value_counts()

sns.displot(data=train_df, x='fine_label', height=6, aspect=2)
plt.xticks(rotation=40)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rescale=1./255
)

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.15,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

# %%
train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='fine_label',
    target_size=(224, 224),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

val_generator = datagen.flow_from_dataframe(
    dataframe=valid_df,
    x_col='filename',
    y_col='fine_label',
    target_size=(224, 224),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

test_generator = datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='filename',
    y_col='fine_label',
    target_size=(224, 224),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# train_subset = train_df.sample(frac=0.1, random_state=42)
# val_subset = valid_df.sample(frac=0.1, random_state=42)

# train_generator = train_datagen.flow_from_dataframe(
#     train_subset,
#     x_col='filename',
#     y_col='fine_label',
#     target_size=(224, 224),
#     batch_size=16,
#     class_mode='categorical'
# )

# val_generator = datagen.flow_from_dataframe(
#     val_subset,
#     x_col='filename',
#     y_col='fine_label',
#     target_size=(224, 224),
#     batch_size=16,
#     class_mode='categorical'
# )
# Out:
# Found 98432 validated image filenames belonging to 8 classes.
# Found 8187 validated image filenames belonging to 8 classes.
# Found 6800 validated image filenames belonging to 8 classes.

# %%
print(train_generator.image_shape)
print(val_generator.image_shape)
print(test_generator.image_shape)
# Out:
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)

# %%
import numpy as np
import matplotlib.pyplot as plt

class_names = ['phyllodes_tumor', 'adenosis', 'fibroadenoma', 'tubular_adenoma','ductal_carcinoma', 'lobular_carcinoma', 'papillary_carcinoma', 'mucinous_carcinoma']

def view_image(generator, col=8, row=2, size=(25, 7)):
    images, labels = next(generator)
    total = len(images)
    plt.figure(figsize=size)
    plt.subplots_adjust(wspace=0.05, hspace=0.15)

    for i in range(total):
        ax = plt.subplot(row, col, i + 1)
        plt.imshow(images[i])
        label_idx = np.argmax(labels[i])
        plt.title(class_names[label_idx])
        plt.axis("off")

    plt.tight_layout()
    plt.show()


view_image(train_generator)

# %%
# data_augmentation = tf.keras.Sequential([
#     layers.RandomFlip("horizontal"),
#     layers.RandomContrast(0.1),
#     layers.RandomBrightness(factor=0.1),
# ])

# %%
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras import optimizers
from keras import Sequential, Model, backend as K
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization, GlobalAveragePooling2D

base_model = DenseNet121(include_top=False,weights='imagenet',input_shape=(224,224,3))

for layer in base_model.layers[:80]:
    layer.trainable = False
for layer in base_model.layers[80:]:
    layer.trainable = True
# Out:
# I0000 00:00:1763051312.329963      48 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1763051312.330667      48 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model = Sequential()

model.add(Input(shape=(224,224,3)))

model.add(base_model)

model.add(GlobalAveragePooling2D())

model.add(Dense(512,activation='gelu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Dense(256,activation='gelu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(Dense(8,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ densenet121 (Functional)        │ (None, 7, 7, 1024)     │     7,037,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │         2,056 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,698,760 (29.37 MB)
#  Trainable params: 6,995,720 (26.69 MB)
#  Non-trainable params: 703,040 (2.68 MB)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger,ReduceLROnPlateau

checkpoint = ModelCheckpoint(
    '/kaggle/working/densenet_on_Breakhis_multiclass_model_epoch_{epoch:02d}_valacc_{val_accuracy:.4f}.weights.h5',
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

early_stop = EarlyStopping(
    monitor='val_accuracy',
    patience=6,
    restore_best_weights=True,
    mode='max',
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_accuracy',      
    factor=0.5,              
    patience=3,              
    verbose=1,               
    min_lr=1e-7              
)

csv_logger = CSVLogger('training_log.csv', append=False)

# %%
model.compile(
        optimizer=optimizers.Adam(learning_rate=1e-3),
        loss='categorical_crossentropy',
        metrics=[
            'accuracy',
            Precision(name='precision'),
            Recall(name='recall'),
            tf.keras.metrics.AUC(name='auc')
        ]
)

# %%
history = model.fit(
    train_generator,
    validation_data = val_generator,
    epochs=12,
    batch_size=BATCH_SIZE,
    callbacks=[checkpoint,reduce_lr,early_stop,csv_logger]
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/12
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763051368.155603     132 service.cc:148] XLA service 0x79fd4411a8a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1763051368.156401     132 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1763051368.156420     132 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1763051375.897766     132 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1763051439.706701     132 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 6152/6152 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.6569 - auc: 0.9239 - loss: 0.9947 - precision: 0.7194 - recall: 0.5917
# Epoch 1: val_accuracy improved from -inf to 0.75241, saving model to /kaggle/working/densenet_on_Breakhis_multiclass_model_epoch_01_valacc_0.7524.weights.h5
# 6152/6152 ━━━━━━━━━━━━━━━━━━━━ 2441s 377ms/step - accuracy: 0.6569 - auc: 0.9239 - loss: 0.9946 - precision: 0.7194 - recall: 0.5917 - val_accuracy: 0.7524 - val_auc: 0.9653 - val_loss: 0.7325 - val_precision: 0.7717 - val_recall: 0.7297 - learning_rate: 0.0010
# Epoch 2/12
# 6152/6152 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.8927 - auc: 0.9918 - loss: 0.3008 - precision: 0.9070 - recall: 0.8803
# Epoch 2: val_accuracy improved from 0.75241 to 0.86674, saving model to /kaggle/working/densenet_on_Breakhis_multiclass_model_epoch_02_valacc_0.8667.weights.h5
# 6152/6152 ━━━━━━━━━━━━━━━━━━━━ 2178s 354ms/step - accuracy: 0.8927 - auc: 0.9918 - loss: 0.3008 - precision: 0.9071 - recall: 0.8803 - val_accuracy: 0.8667 - val_auc: 0.9859 - val_loss: 0.4027 - val_precision: 0.8743 - val_recall: 0.8620 - learning_rate: 0.0010
# Epoch 3/12
# 6152/6152 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.9356 - auc: 0.9959 - loss: 0.1915 - precision: 0.9420 - recall: 0.9298
# Epoch 3: val_accuracy improved from 0.86674 to 0.88628, saving model to /kaggle/working/densenet_on_Breakhis_multiclass_model_epoch_03_valacc_0.8863.weights.h5
# 6152/6152 ━━━━━━━━━━━━━━━━━━━━ 2176s 354ms/step - accuracy: 0.9356 - auc: 0.9959 - loss: 0.1915 - precision: 0.9420 - recall: 0.9298 - val_accuracy: 0.8863 - val_auc: 0.9877 - val_loss: 0.3367 - val_precision: 0.8923 - val_recall: 0.8818 - learning_rate: 0.0010
# Epoch 4/12
# 6152/6152 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.9526 - auc: 0.9976 - loss: 0.1386 - precision: 0.9563 - recall: 0.9491
# Epoch 4: val_accuracy improved from 0.88628 to 0.90839, saving model to /kaggle/working/densenet_on_Breakhis_multiclass_model_epoch_04_valacc_0.9084.weights.h5
# 6152/6152 ━━━━━━━━━━━━━━━━━━━━ 2165s 352ms/step - accuracy: 0.9526 - auc: 0.9976 - loss: 0.1386 - precision: 0.9563 - recall: 0.9491 - val_accuracy: 0.9084 - val_auc: 0.9926 - val_loss: 0.2794 - val_precision: 0.9123 - val_recall: 0.9052 - learning_rate: 0.0010
# Epoch 5/12
# 6152/6152 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.9595 - auc: 0.9981 - loss: 0.1173 - precision: 0.9628 - recall: 0.9573
# Epoch 5: val_accuracy did not improve from 0.90839
# 6152/6152 ━━━━━━━━━━━━━━━━━━━━ 2134s 347ms/step - accuracy: 0.9595 - auc: 0.9981 - loss: 0.1173 - precision: 0.9628 - recall: 0.9573 - val_accuracy: 0.8499 - val_auc: 0.9794 - val_loss: 0.5056 - val_precision: 0.8534 - val_recall: 0.8467 - learning_rate: 0.0010
# Epoch 6/12
# 6152/6152 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.9665 - auc: 0.9986 - loss: 0.0981 - precision: 0.9688 - recall: 0.9646
# Epoch 6: val_accuracy improved from 0.90839 to 0.94113, saving model to /kaggle/working/densenet_on_Breakhis_multiclass_model_epoch_06_valacc_0.9411.weights.h5
# 6152/6152 ━━━━━━━━━━━━━━━━━━━━ 2197s 357ms/step - accuracy: 0.9665 - auc: 0.9986 - loss: 0.0981 - precision: 0.9688 - recall: 0.9646 - val_accuracy: 0.9411 - val_auc: 0.9954 - val_loss: 0.1828 - val_precision: 0.9423 - val_recall: 0.9397 - learning_rate: 0.0010
# Epoch 7/12
# 6152/6152 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.9718 - auc: 0.9988 - loss: 0.0833 - precision: 0.9733 - recall: 0.9703
# Epoch 7: val_accuracy improved from 0.94113 to 0.94821, saving model to /kaggle/working/densenet_on_Breakhis_multiclass_model_epoch_07_valacc_0.9482.weights.h5
# 6152/6152 ━━━━━━━━━━━━━━━━━━━━ 2246s 365ms/step - accuracy: 0.9718 - auc: 0.9988 - loss: 0.0833 - precision: 0.9733 - recall: 0.9703 - val_accuracy: 0.9482 - val_auc: 0.9955 - val_loss: 0.1782 - val_precision: 0.9503 - val_recall: 0.9464 - learning_rate: 0.0010
# Epoch 8/12
# 6152/6152 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.9733 - auc: 0.9991 - loss: 0.0768 - precision: 0.9748 - recall: 0.9722
# Epoch 8: val_accuracy did not improve from 0.94821
# 6152/6152 ━━━━━━━━━━━━━━━━━━━━ 2212s 360ms/step - accuracy: 0.9733 - auc: 0.9991 - loss: 0.0768 - precision: 0.9748 - recall: 0.9722 - val_accuracy: 0.9040 - val_auc: 0.9872 - val_loss: 0.3930 - val_precision: 0.9056 - val_recall: 0.9024 - learning_rate: 0.0010
# Epoch 9/12
# 6152/6152 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.9759 - auc: 0.9991 - loss: 0.0701 - precision: 0.9772 - recall: 0.9747
# Epoch 9: val_accuracy did not improve from 0.94821
# 6152/6152 ━━━━━━━━━━━━━━━━━━━━ 2282s 371ms/step - accuracy: 0.9759 - auc: 0.9991 - loss: 0.0701 - precision: 0.9772 - recall: 0.9747 - val_accuracy: 0.8686 - val_auc: 0.9848 - val_loss: 0.4206 - val_precision: 0.8696 - val_recall: 0.8674 - learning_rate: 0.0010
# Epoch 10/12
# 6152/6152 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.9794 - auc: 0.9992 - loss: 0.0618 - precision: 0.9805 - recall: 0.9786
# Epoch 10: val_accuracy improved from 0.94821 to 0.96946, saving model to /kaggle/working/densenet_on_Breakhis_multiclass_model_epoch_10_valacc_0.9695.weights.h5
# 6152/6152 ━━━━━━━━━━━━━━━━━━━━ 2239s 364ms/step - accuracy: 0.9794 - auc: 0.9992 - loss: 0.0618 - precision: 0.9805 - recall: 0.9786 - val_accuracy: 0.9695 - val_auc: 0.9988 - val_loss: 0.1011 - val_precision: 0.9697 - val_recall: 0.9691 - learning_rate: 0.0010
# Epoch 11/12
# 6152/6152 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.9792 - auc: 0.9993 - loss: 0.0619 - precision: 0.9800 - recall: 0.9783
# Epoch 11: val_accuracy did not improve from 0.96946
# 6152/6152 ━━━━━━━━━━━━━━━━━━━━ 2262s 368ms/step - accuracy: 0.9792 - auc: 0.9993 - loss: 0.0619 - precision: 0.9800 - recall: 0.9783 - val_accuracy: 0.9227 - val_auc: 0.9931 - val_loss: 0.2428 - val_precision: 0.9234 - val_recall: 0.9222 - learning_rate: 0.0010
# Epoch 12/12
# 6152/6152 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.9817 - auc: 0.9994 - loss: 0.0543 - precision: 0.9825 - recall: 0.9811
# Epoch 12: val_accuracy did not improve from 0.96946
# 6152/6152 ━━━━━━━━━━━━━━━━━━━━ 2315s 376ms/step - accuracy: 0.9817 - auc: 0.9994 - loss: 0.0543 - precision: 0.9825 - recall: 0.9811 - val_accuracy: 0.8866 - val_auc: 0.9842 - val_loss: 0.4270 - val_precision: 0.8891 - val_recall: 0.8863 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 10.

# %%
loss, accuracy,auc,precision,recall = model.evaluate(test_generator, verbose=1)

print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy*100:.2f}%")
print(f"Test Precision: {precision*100:.2f}%")
print(f"Test Recall: {recall*100:.2f}%")
# Out:
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 92s 216ms/step - accuracy: 0.9837 - auc: 0.9995 - loss: 0.0522 - precision: 0.9840 - recall: 0.9837
# Test Loss: 0.0473
# Test Accuracy: 98.60%
# Test Precision: 98.60%
# Test Recall: 99.92%

# %%
def plot_history(history):
    val_loss = history.history['val_loss' ]
    loss =     history.history['loss' ]
    acc =      history.history['accuracy' ]
    val_acc =  history.history['val_accuracy' ]

    epochs    = range(1,len(acc)+1,1)

    plt.plot  ( epochs,     acc, 'r--', label='Training acc'  )
    plt.plot  ( epochs, val_acc,  'b', label='Validation acc')
    plt.title ('Training and validation accuracy')
    plt.ylabel('acc')
    plt.xlabel('epochs')
    plt.legend()

    plt.figure()

    plt.plot  ( epochs,     loss, 'r--', label='Training loss' )
    plt.plot  ( epochs, val_loss ,  'b', label='Validation loss' )
    plt.title ('Training and validation loss')
    plt.ylabel('loss')
    plt.xlabel('epochs')
    plt.legend()

    plt.figure()

# %%
plot_history(history)

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# -------------------------------
# 1. Predict labels for test set
# -------------------------------
y_pred_probs = model.predict(test_generator)       # predicted probabilities
y_pred = np.argmax(y_pred_probs, axis=1)           # predicted class indices
y_true = test_generator.classes                    # true class indices

# -------------------------------
# 2. Compute confusion matrix
# -------------------------------
cm = confusion_matrix(y_true, y_pred)

# -------------------------------
# 3. Display confusion matrix
# -------------------------------
plt.figure(figsize=(8, 8))
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=list(test_generator.class_indices.keys())
)
disp.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
plt.title("Confusion Matrix -  Labels")
plt.show()
# Out:
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 100s 210ms/step

# %%
df = pd.DataFrame(history.history)
df['epoch'] = range(1, len(df) + 1)

df.to_csv('training_history.csv', index=False)
